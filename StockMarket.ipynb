# %%
#import libraries
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np

# %%
#defining a list of assets that will be analized
assets=["AAPL","MSFT","TSLA","MMM"]

# %%
#pulling data for the assest by using yfinace and providing the period frame
df=yf.download(assets,period="1y")
# Out:
# [*********************100%%**********************]  4 of 4 completed

# %%
#print df
df
# Out:
# Price        Adj Close                                           Close  \
# Ticker            AAPL         MMM        MSFT        TSLA        AAPL
# Date
# 2023-06-06  178.263306   77.153839  331.089996  221.309998  179.210007
# 2023-06-07  176.880630   79.281075  320.869934  224.570007  177.820007
# 2023-06-08  179.616104   79.092690  322.735382  234.860001  180.570007
# 2023-06-09  180.004059   78.417625  324.253479  244.399994  180.960007
# 2023-06-12  182.819092   79.485168  329.274170  249.830002  183.789993
# ...                ...         ...         ...         ...         ...
# 2024-05-30  191.289993   98.199997  414.670013  178.789993  191.289993
# 2024-05-31  192.250000  100.139999  415.130005  178.080002  192.250000
# 2024-06-03  194.029999   99.760002  413.519989  176.289993  194.029999
# 2024-06-04  194.350006   98.610001  416.070007  174.770004  194.350006
# 2024-06-05  195.869995   99.059998  424.010010  175.000000  195.869995
#
# ...

# %%
#for this analysis Adj close is only column needed
df['Adj Close']
# Out:
# Ticker            AAPL         MMM        MSFT        TSLA
# Date
# 2023-06-06  178.263306   77.153839  331.089996  221.309998
# 2023-06-07  176.880630   79.281075  320.869934  224.570007
# 2023-06-08  179.616104   79.092690  322.735382  234.860001
# 2023-06-09  180.004059   78.417625  324.253479  244.399994
# 2023-06-12  182.819092   79.485168  329.274170  249.830002
# ...                ...         ...         ...         ...
# 2024-05-30  191.289993   98.199997  414.670013  178.789993
# 2024-05-31  192.250000  100.139999  415.130005  178.080002
# 2024-06-03  194.029999   99.760002  413.519989  176.289993
# 2024-06-04  194.350006   98.610001  416.070007  174.770004
# 2024-06-05  195.869995   99.059998  424.010010  175.000000
#
# [252 rows x 4 columns]

# %%
prices=df['Adj Close']

# %%
prices
# Out:
# Ticker            AAPL         MMM        MSFT        TSLA
# Date
# 2023-06-06  178.263306   77.153839  331.089996  221.309998
# 2023-06-07  176.880630   79.281075  320.869934  224.570007
# 2023-06-08  179.616104   79.092690  322.735382  234.860001
# 2023-06-09  180.004059   78.417625  324.253479  244.399994
# 2023-06-12  182.819092   79.485168  329.274170  249.830002
# ...                ...         ...         ...         ...
# 2024-05-30  191.289993   98.199997  414.670013  178.789993
# 2024-05-31  192.250000  100.139999  415.130005  178.080002
# 2024-06-03  194.029999   99.760002  413.519989  176.289993
# 2024-06-04  194.350006   98.610001  416.070007  174.770004
# 2024-06-05  195.869995   99.059998  424.010010  175.000000
#
# [252 rows x 4 columns]

# %%
#daily returns of apple for a given day
176.880646/178.263306-1
# Out:
# -0.007756279354540818

# %%
#getting the daily change in each assets
prices.pct_change(fill_method=None)
# Out:
# Ticker          AAPL       MMM      MSFT      TSLA
# Date
# 2023-06-06       NaN       NaN       NaN       NaN
# 2023-06-07 -0.007756  0.027571 -0.030868  0.014731
# 2023-06-08  0.015465 -0.002376  0.005814  0.045821
# 2023-06-09  0.002160 -0.008535  0.004704  0.040620
# 2023-06-12  0.015639  0.013614  0.015484  0.022218
# ...              ...       ...       ...       ...
# 2024-05-30  0.005255  0.006560 -0.033786  0.014757
# 2024-05-31  0.005019  0.019756  0.001109 -0.003971
# 2024-06-03  0.009259 -0.003795 -0.003878 -0.010052
# 2024-06-04  0.001649 -0.011528  0.006167 -0.008622
# 2024-06-05  0.007821  0.004563  0.019083  0.001316
#
# [252 rows x 4 columns]

# %%
#finidng how apple was performing from a certain date to another
(0.022816+1)*(-0.009722 +1)
# Out:
# 1.0128721828479998

# %%
#storing returns in this variable
returns=prices.pct_change(fill_method=None)
returns
# Out:
# Ticker          AAPL       MMM      MSFT      TSLA
# Date
# 2023-06-06       NaN       NaN       NaN       NaN
# 2023-06-07 -0.007756  0.027571 -0.030868  0.014731
# 2023-06-08  0.015465 -0.002376  0.005814  0.045821
# 2023-06-09  0.002160 -0.008535  0.004704  0.040620
# 2023-06-12  0.015639  0.013614  0.015484  0.022218
# ...              ...       ...       ...       ...
# 2024-05-30  0.005255  0.006560 -0.033786  0.014757
# 2024-05-31  0.005019  0.019756  0.001109 -0.003971
# 2024-06-03  0.009259 -0.003795 -0.003878 -0.010052
# 2024-06-04  0.001649 -0.011528  0.006167 -0.008622
# 2024-06-05  0.007821  0.004563  0.019083  0.001316
#
# [252 rows x 4 columns]

# %%
#cumulative return in all rows,also know how much stock market was rising from 2023-2024
(returns+1).cumprod()-1
cum_ret=(returns+1).cumprod()-1
cum_ret
# Out:
# Ticker          AAPL       MMM      MSFT      TSLA
# Date
# 2023-06-06       NaN       NaN       NaN       NaN
# 2023-06-07 -0.007756  0.027571 -0.030868  0.014731
# 2023-06-08  0.007589  0.025130 -0.025234  0.061226
# 2023-06-09  0.009765  0.016380 -0.020649  0.104333
# 2023-06-12  0.025556  0.030217 -0.005484  0.128869
# ...              ...       ...       ...       ...
# 2024-05-30  0.073076  0.272782  0.252439 -0.192129
# 2024-05-31  0.078461  0.297926  0.253828 -0.195337
# 2024-06-03  0.088446  0.293001  0.248966 -0.203425
# 2024-06-04  0.090241  0.278096  0.256667 -0.210293
# 2024-06-05  0.098768  0.283928  0.280649 -0.209254
#
# [252 rows x 4 columns]

# %%
cum_ret.plot(figsize=(10,6))
# Out:
# <Axes: xlabel='Date'>

# %%
#volatility-mesasurement usually calculated using standard deviation(showing how much the assest is wining around it own mean
returns.std()
# Out:
# Ticker
# AAPL    0.012754
# MMM     0.017225
# MSFT    0.013185
# TSLA    0.032191
# dtype: float64

# %%
returns
# Out:
# Ticker          AAPL       MMM      MSFT      TSLA
# Date
# 2023-06-06       NaN       NaN       NaN       NaN
# 2023-06-07 -0.007756  0.027571 -0.030868  0.014731
# 2023-06-08  0.015465 -0.002376  0.005814  0.045821
# 2023-06-09  0.002160 -0.008535  0.004704  0.040620
# 2023-06-12  0.015639  0.013614  0.015484  0.022218
# ...              ...       ...       ...       ...
# 2024-05-30  0.005255  0.006560 -0.033786  0.014757
# 2024-05-31  0.005019  0.019756  0.001109 -0.003971
# 2024-06-03  0.009259 -0.003795 -0.003878 -0.010052
# 2024-06-04  0.001649 -0.011528  0.006167 -0.008622
# 2024-06-05  0.007821  0.004563  0.019083  0.001316
#
# [252 rows x 4 columns]

# %%
#Volatility chart 
returns["AAPL"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#return distribution
returns["AAPL"].hist(bins=50)
# Out:
# <Axes: >

# %%
returns.columns[0]
# Out:
# 'AAPL'

# %%
#Visual comparison of multiple assets using subplots
fig,ax =plt.subplots(2,2, figsize=(16,5))
plt.subplots_adjust(bottom=0.1, top=0.9, wspace=0.3, hspace=0.4)

Counter=0
for i in range(2):
    for j in range(2):
        ax[i,j].plot(returns[returns.columns[Counter]])
        ax[i,j].set_title(returns.columns[Counter])
        Counter +=1

# %%
#Visual comparison of multiple assets for Return distributions
fig,ax =plt.subplots(2,2, figsize=(16,5))
plt.subplots_adjust(bottom=0.1, top=0.9, wspace=0.3, hspace=0.4)

Counter=0
for i in range(2):
    for j in range(2):
        ax[i,j].hist(returns[returns.columns[Counter]],bins=50)
        ax[i,j].set_title(returns.columns[Counter])
        Counter +=1

# %%
#correlation analysis
returns.corr()
# Out:
# Ticker      AAPL       MMM      MSFT      TSLA
# Ticker
# AAPL    1.000000  0.095612  0.458717  0.364139
# MMM     0.095612  1.000000  0.061124  0.054049
# MSFT    0.458717  0.061124  1.000000  0.236561
# TSLA    0.364139  0.054049  0.236561  1.000000

# %%
import seaborn as sns

# %%
#correlation of different asset :The lighter the number the higher the correlation
sns.heatmap(returns.corr())
# Out:
# <Axes: xlabel='Ticker', ylabel='Ticker'>

# %%
#logarithmic returns 
np.log(1+returns)
# Out:
# Ticker          AAPL       MMM      MSFT      TSLA
# Date
# 2023-06-06       NaN       NaN       NaN       NaN
# 2023-06-07 -0.007787  0.027198 -0.031354  0.014623
# 2023-06-08  0.015347 -0.002379  0.005797  0.044802
# 2023-06-09  0.002158 -0.008572  0.004693  0.039817
# 2023-06-12  0.015518  0.013522  0.015365  0.021974
# ...              ...       ...       ...       ...
# 2024-05-30  0.005241  0.006539 -0.034370  0.014649
# 2024-05-31  0.005006  0.019563  0.001109 -0.003979
# 2024-06-03  0.009216 -0.003802 -0.003886 -0.010103
# 2024-06-04  0.001648 -0.011595  0.006148 -0.008659
# 2024-06-05  0.007790  0.004553  0.018904  0.001315
#
# [252 rows x 4 columns]

# %%
returns
# Out:
# Ticker          AAPL       MMM      MSFT      TSLA
# Date
# 2023-06-06       NaN       NaN       NaN       NaN
# 2023-06-07 -0.007756  0.027571 -0.030868  0.014731
# 2023-06-08  0.015465 -0.002376  0.005814  0.045821
# 2023-06-09  0.002160 -0.008535  0.004704  0.040620
# 2023-06-12  0.015639  0.013614  0.015484  0.022218
# ...              ...       ...       ...       ...
# 2024-05-30  0.005255  0.006560 -0.033786  0.014757
# 2024-05-31  0.005019  0.019756  0.001109 -0.003971
# 2024-06-03  0.009259 -0.003795 -0.003878 -0.010052
# 2024-06-04  0.001649 -0.011528  0.006167 -0.008622
# 2024-06-05  0.007821  0.004563  0.019083  0.001316
#
# [252 rows x 4 columns]
